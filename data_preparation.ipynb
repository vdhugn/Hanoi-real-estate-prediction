# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HREP/crawled.csv')
df.head()
# Out:
#      price    area           type        district          road_width  \
# 0   4.1 Tỷ   39 m²  Nhà trong ngõ  Quận Hoàng Mai                 NaN
# 1     4 Tỷ   40 m²  Nhà trong ngõ     Quận Tây Hồ                 NaN
# 2  13.8 Tỷ   70 m²    Nhà mặt phố    Quận Hà Đông  Đường vào: Rộng 8m
# 3   138 Tỷ  230 m²    Nhà mặt phố  Quận Hoàn Kiếm                 NaN
# 4  10.9 Tỷ   57 m²    Nhà mặt phố  Quận Hoàng Mai                 NaN
#
#             width  floors parking_slots     bedrooms bathrooms
# 0             NaN  4 tầng           NaN  4 Phòng ngủ      3 WC
# 1             NaN  4 tầng           NaN  4 Phòng ngủ      4 WC
# 2  Mặt tiền: 4.5m  4 tầng  1 Chỗ để ôtô  4 Phòng ngủ      3 WC
# 3             NaN     NaN           NaN          NaN       NaN
# 4    Mặt tiền: 5m  4 tầng           NaN          NaN       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20088 entries, 0 to 20087
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          19513 non-null  object
#  1   area           20088 non-null  object
#  2   type           20088 non-null  object
#  3   district       19487 non-null  object
#  4   road_width     14026 non-null  object
#  5   width          15186 non-null  object
#  6   floors         16904 non-null  object
#  7   parking_slots  5747 non-null   object
#  8   bedrooms       14588 non-null  object
#  9   bathrooms      12561 non-null  object
# dtypes: object(10)
# memory usage: 1.5+ MB

# %%
df.drop(columns='bathrooms', inplace=True)

# %%
def fix_price(x):
    try:
        x = x.split()
        if x[1] == 'Tỷ':
            return round(float(x[0]), 2)
        elif x[1] == 'Triệu':
            return round(float(x[0]) / 1000, 2)
    except:
        return None

df['price'] = df['price'].apply(fix_price)
df.head()
# Out:
#    price    area           type        district          road_width  \
# 0    4.1   39 m²  Nhà trong ngõ  Quận Hoàng Mai                 NaN
# 1    4.0   40 m²  Nhà trong ngõ     Quận Tây Hồ                 NaN
# 2   13.8   70 m²    Nhà mặt phố    Quận Hà Đông  Đường vào: Rộng 8m
# 3  138.0  230 m²    Nhà mặt phố  Quận Hoàn Kiếm                 NaN
# 4   10.9   57 m²    Nhà mặt phố  Quận Hoàng Mai                 NaN
#
#             width  floors parking_slots     bedrooms
# 0             NaN  4 tầng           NaN  4 Phòng ngủ
# 1             NaN  4 tầng           NaN  4 Phòng ngủ
# 2  Mặt tiền: 4.5m  4 tầng  1 Chỗ để ôtô  4 Phòng ngủ
# 3             NaN     NaN           NaN          NaN
# 4    Mặt tiền: 5m  4 tầng           NaN          NaN

# %%
df['area'] = df['area'].apply(lambda x: float(x.split()[0]))

# %%
def fix_width(x):
    try:
        return float(x.split()[-1][:-1])
    except:
        return None
            
df['road_width'] = df['road_width'].apply(str).apply(fix_width)
df['width'] = df['width'].apply(str).apply(fix_width)
df.head()
# Out:
#    price   area           type        district  road_width  width  floors  \
# 0    4.1   39.0  Nhà trong ngõ  Quận Hoàng Mai         NaN    NaN  4 tầng
# 1    4.0   40.0  Nhà trong ngõ     Quận Tây Hồ         NaN    NaN  4 tầng
# 2   13.8   70.0    Nhà mặt phố    Quận Hà Đông         8.0    4.5  4 tầng
# 3  138.0  230.0    Nhà mặt phố  Quận Hoàn Kiếm         NaN    NaN     NaN
# 4   10.9   57.0    Nhà mặt phố  Quận Hoàng Mai         NaN    5.0  4 tầng
#
#   parking_slots     bedrooms
# 0           NaN  4 Phòng ngủ
# 1           NaN  4 Phòng ngủ
# 2  1 Chỗ để ôtô  4 Phòng ngủ
# 3           NaN          NaN
# 4           NaN          NaN

# %%
def fix_floors(x):
    try:
        try:
            return int(x.split()[0])
        except:
            return int(float(x.split()[0]) + 0.5)
    except:
        return None
    
df['floors'] = df['floors'].apply(fix_floors)
df.head()
# Out:
#    price   area           type        district  road_width  width  floors  \
# 0    4.1   39.0  Nhà trong ngõ  Quận Hoàng Mai         NaN    NaN     4.0
# 1    4.0   40.0  Nhà trong ngõ     Quận Tây Hồ         NaN    NaN     4.0
# 2   13.8   70.0    Nhà mặt phố    Quận Hà Đông         8.0    4.5     4.0
# 3  138.0  230.0    Nhà mặt phố  Quận Hoàn Kiếm         NaN    NaN     NaN
# 4   10.9   57.0    Nhà mặt phố  Quận Hoàng Mai         NaN    5.0     4.0
#
#   parking_slots     bedrooms
# 0           NaN  4 Phòng ngủ
# 1           NaN  4 Phòng ngủ
# 2  1 Chỗ để ôtô  4 Phòng ngủ
# 3           NaN          NaN
# 4           NaN          NaN

# %%
def fix_parking(x):
    try:
        return int(x.split()[0])
    except:
        return 0
    
df['parking_slots'] = df['parking_slots'].apply(fix_parking)
df.head()
# Out:
#    price   area           type        district  road_width  width  floors  \
# 0    4.1   39.0  Nhà trong ngõ  Quận Hoàng Mai         NaN    NaN     4.0
# 1    4.0   40.0  Nhà trong ngõ     Quận Tây Hồ         NaN    NaN     4.0
# 2   13.8   70.0    Nhà mặt phố    Quận Hà Đông         8.0    4.5     4.0
# 3  138.0  230.0    Nhà mặt phố  Quận Hoàn Kiếm         NaN    NaN     NaN
# 4   10.9   57.0    Nhà mặt phố  Quận Hoàng Mai         NaN    5.0     4.0
#
#    parking_slots     bedrooms
# 0              0  4 Phòng ngủ
# 1              0  4 Phòng ngủ
# 2              1  4 Phòng ngủ
# 3              0          NaN
# 4              0          NaN

# %%
def fix_rooms(x):
    try:
        return int(x.split()[0])
    except:
        return None

df['bedrooms'] = df['bedrooms'].apply(fix_rooms)
df.head()
# Out:
#    price   area           type        district  road_width  width  floors  \
# 0    4.1   39.0  Nhà trong ngõ  Quận Hoàng Mai         NaN    NaN     4.0
# 1    4.0   40.0  Nhà trong ngõ     Quận Tây Hồ         NaN    NaN     4.0
# 2   13.8   70.0    Nhà mặt phố    Quận Hà Đông         8.0    4.5     4.0
# 3  138.0  230.0    Nhà mặt phố  Quận Hoàn Kiếm         NaN    NaN     NaN
# 4   10.9   57.0    Nhà mặt phố  Quận Hoàng Mai         NaN    5.0     4.0
#
#    parking_slots  bedrooms
# 0              0       4.0
# 1              0       4.0
# 2              1       4.0
# 3              0       NaN
# 4              0       NaN

# %%
df = df[(df['price'] >= 0.5) & (df['price'] <= 50)]
df = df[(df['area'] >= 10) & (df['area'] <= 200)]
df = df[(df['road_width'] >= 0.5) & (df['road_width'] <= 40)]
df = df[(df['width'] >= 2) & (df['width'] <= 15)]
df = df[(df['floors'] >= 0) & (df['floors'] <= 10)]
df = df[(df['parking_slots'] >= 0) & (df['parking_slots'] <= 5)]
df = df[(df['bedrooms'] >= 1) & (df['bedrooms'] <= 20)]

# %%
df_no_nan = df.dropna()
test_df = df_no_nan.sample(n=1000, random_state=42)
test_df
# Out:
#        price   area           type           district  road_width  width  \
# 9386    5.00   40.0  Nhà trong ngõ      Quận Cầu Giấy         3.0    3.8
# 16075   6.00   30.0  Nhà trong ngõ       Quận Đống Đa         3.0    6.0
# 3599   31.00  138.0    Nhà mặt phố  Quận Hai Bà Trưng        20.0    7.0
# 19776   4.95   40.0  Nhà trong ngõ       Quận Ba Đình         3.0    4.5
# 11728   2.80   35.0  Nhà trong ngõ       Quận Hà Đông         3.0    3.5
# ...      ...    ...            ...                ...         ...    ...
# 14372  35.00   86.0    Nhà mặt phố       Quận Ba Đình        20.0    6.6
# 4589    2.82   38.0  Nhà trong ngõ   Quận Bắc Từ Liêm         1.5    4.6
# 16970   3.75   33.0  Nhà trong ngõ       Quận Ba Đình         3.0    4.0
# 228    10.60   51.0    Nhà mặt phố      Quận Cầu Giấy         8.0    4.0
# 4011    4.10   40.0  Nhà trong ngõ       Quận Hà Đông         4.0    4.0
#
#        floors  parking_slots  bedrooms
# 9386      4.0              0       4.0
# 16075     5.0              0       3.0
# 3599      7.0              4      10.0
# 19776     5.0              0       4.0
# 11728     4.0              1       3.0
# ...       ...            ...       ...
# 14372     6.0              0       6.0
# 4589      3.0              0       3.0
# 16970     5.0              0       3.0
# 228       5.0              1       3.0
# 4011      5.0              0       4.0
#
# [1000 rows x 9 columns]

# %%
mean_road_width_by_type = df.groupby('type')['road_width'].transform('mean').round(1)
df['road_width'].fillna(mean_road_width_by_type, inplace=True)

# %%
mean_width = df['width'].mean().round(1)
df['width'].fillna(mean_width, inplace=True)

# %%
mode_floors = df['floors'].mode()[0]
df['floors'].fillna(mode_floors, inplace=True)

# %%
mode_bedrooms_by_floors = df.groupby('floors')['bedrooms'].transform(lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan)
df['bedrooms'].fillna(mode_bedrooms_by_floors, inplace=True)

# %%
df.head()
# Out:
#     price  area           type           district  road_width  width  floors  \
# 2    13.8  70.0    Nhà mặt phố       Quận Hà Đông         8.0    4.5     4.0
# 5     2.6  28.0  Nhà trong ngõ       Quận Đống Đa         2.5    3.2     4.0
# 6     7.8  33.0    Nhà mặt phố    Quận Thanh Xuân         6.0    3.5     4.0
# 7     7.3  36.0    Nhà mặt phố    Quận Thanh Xuân         6.0    4.5     3.0
# 10   21.0  80.0    Nhà mặt phố  Quận Hai Bà Trưng         6.0    6.0     6.0
#
#     parking_slots  bedrooms
# 2               1       4.0
# 5               0       3.0
# 6               0       3.0
# 7               0       2.0
# 10              0       6.0

# %%
df.isnull().sum()
# Out:
# price              0
# area               0
# type               0
# district         305
# road_width         0
# width              0
# floors             0
# parking_slots      0
# bedrooms           0
# dtype: int64

# %%
df.describe()
# Out:
#               price          area    road_width         width        floors  \
# count  10052.000000  10052.000000  10052.000000  10052.000000  10052.000000
# mean       9.843254     55.538132      7.248426      4.761668      4.743733
# std        8.944636     26.525176      7.288741      1.581016      1.379089
# min        0.500000     12.000000      1.000000      2.000000      1.000000
# 25%        4.000000     38.000000      3.000000      4.000000      4.000000
# 50%        6.400000     48.000000      4.000000      4.200000      5.000000
# 75%       12.500000     65.000000      8.000000      5.000000      5.000000
# max       50.000000    200.000000     40.000000     15.000000     10.000000
#
#        parking_slots      bedrooms
# count   10052.000000  10052.000000
# mean        0.894150      4.477915
# std         1.372998      2.080895
# min         0.000000      1.000000
# 25%         0.000000      3.000000
# 50%         0.000000      4.000000
# 75%         1.000000      5.000000
# max         5.000000     17.000000

# %%
df.dropna(inplace=True)
df.head()
# Out:
#     price  area           type           district  road_width  width  floors  \
# 2    13.8  70.0    Nhà mặt phố       Quận Hà Đông         8.0    4.5     4.0
# 5     2.6  28.0  Nhà trong ngõ       Quận Đống Đa         2.5    3.2     4.0
# 6     7.8  33.0    Nhà mặt phố    Quận Thanh Xuân         6.0    3.5     4.0
# 7     7.3  36.0    Nhà mặt phố    Quận Thanh Xuân         6.0    4.5     3.0
# 10   21.0  80.0    Nhà mặt phố  Quận Hai Bà Trưng         6.0    6.0     6.0
#
#     parking_slots  bedrooms
# 2               1       4.0
# 5               0       3.0
# 6               0       3.0
# 7               0       2.0
# 10              0       6.0

# %%
price_ranges = [i for i in range(0, 51, 5)] 
price_counts = df['price'].groupby(pd.cut(df['price'], bins=price_ranges)).count()

plt.figure(figsize=(8, 6))
price_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Price Ranges')
plt.ylabel('Count')
plt.title('Count of Prices within Different Ranges')
plt.xticks(rotation=90)
plt.show()

# %%
area_ranges = [i for i in range(10, 200, 10)] 
area_counts = df['area'].groupby(pd.cut(df['area'], bins=area_ranges)).count()

plt.figure(figsize=(10, 6))
area_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Area Ranges')
plt.ylabel('Count')
plt.title('Count of Areas within Different Ranges')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(2, 8))

sns.boxplot(data=df, x='type', y='price')
plt.xlabel('Type')
plt.ylabel('Price')
plt.title('Price Box Plots by Type')
plt.xticks(rotation=90)  
plt.show()

# %%
median_prices = df.groupby('district')['price'].median().sort_values(ascending=False)

df['district'] = pd.Categorical(df['district'], categories=median_prices.index, ordered=True)
df_sorted = df.sort_values('district')

plt.figure(figsize=(12, 8))

sns.boxplot(data=df_sorted, x='district', y='price')
plt.xlabel('Districts')
plt.ylabel('Price')
plt.title('Price Box Plots across District (Sorted by Median Price)')
plt.xticks(rotation=90)  
plt.show()

# %%
encoding = {
    'Nhà trong ngõ': 0,
    'Nhà mặt phố': 1
}

df['type'] = df['type'].map(encoding)
df = pd.get_dummies(df, columns=['district'], drop_first=True)

# %%
correlation_matrix = abs(df.corr())

plt.figure(figsize=(20, 15))
sns.heatmap(correlation_matrix, annot=True, annot_kws={"size": 10}, fmt='.2f', vmin=0, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
test_mask = df.index.isin(test_df.index)

train = df[~test_mask]
test = df[test_mask]

# %%
train.to_csv('data/train.csv', index=False)
test.to_csv('data/test.csv', index=False)
